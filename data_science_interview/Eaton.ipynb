# %%
FD = 1%
non FD = 99%
TPR = .92%
FPR =.08%
FPC = 10 Dollor
FNC = 500 Dollor
Trabsation =1 M--> 100, 0000 *92 => 9200 

TP ==> 9200000 --> 
FP ==> 80000

# %%
we have to identity cost

Frudent transaction : 1%
non Frudent transaction : 99%

TPR = .92%
FPR =.08%
False Postive cost = 10 Dollor
False Negative cost = 500 Dollor
Trasation =1 M
# Out:
#   Cell In[2], line 1
#     we have to identity cost
#        ^
# SyntaxError: invalid syntax

# %%
select depart, salary, employee_depart from employee_table where salary in (select ((max(salary)) from employee table groupy by depart)
