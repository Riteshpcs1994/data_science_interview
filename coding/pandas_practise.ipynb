# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/ritkumar17/Desktop/R&D_Project/data_science_interview/data_science_interview/Bank Customer Historic Data.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
# implemnet logistics regression:
import numpy as np

# %%
def sigmoid(z):
    return (1/(1+np.exp(-z)))

class LogisticRegression:
    def __init__(self, learning_rate=0.01, n_iterations=1000):
        self.learning_rate = learning_rate
        self.n_iterations = n_iterations
        self.weights = None
        self.bais = None

    def fit(self, X, y):
        n_samples, n_feature = X.shape
        self.weights = np.zeros(n_feature)
        self.bais = 0

        for _ in range(self.n_iterations):
            linear_model = np.dot(X, self.weights) + self.bais
            y_predicted = sigmoid(linear_model)

            dw = (1/n_samples) * np.dot(X.T, (y_predicted-y))
            db = (1/n_samples) * np.sum(y_predicted-y)

            self.weights -= self.learning_rate * dw
            self.bais -= self.learning_rate * db 

    def predict_prob(self, X):
        linear_model = np.dot(X, self.weights) + self.bias
        return sigmoid(linear_model)

    def predict(self, x, threshold = 0.5):
        y_prob = self.predict_prob(X)
        return np.where(y_prob >= threshold,1,0)

# %% [markdown]
# ### Group By

# %%
import pandas as pd
data_df = pd.read_csv("/Users/ritkumar17/Desktop/R&D_Project/data_science_interview/data_science_interview/train_v9rqX0R.csv")

# %%
data_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# So let’s find out the total sales for each location type:

# %%
data_df.groupby("Outlet_Location_Type")["Item_Outlet_Sales"].sum()
# Out:
# Outlet_Location_Type
# Tier 1    4.482059e+06
# Tier 2    6.472314e+06
# Tier 3    7.636753e+06
# Name: Item_Outlet_Sales, dtype: float64

# %%
data_df.groupby("Outlet_Location_Type")["Item_Weight"].agg([np.mean, np.median])
# Out:
# /var/folders/00/rndss5vd6h9cdr24fwvnz6kw0000gp/T/ipykernel_56273/3392480614.py:1: FutureWarning: The provided callable <function mean at 0x103c54680> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data_df.groupby("Outlet_Location_Type")["Item_Weight"].agg([np.mean, np.median])
# /var/folders/00/rndss5vd6h9cdr24fwvnz6kw0000gp/T/ipykernel_56273/3392480614.py:1: FutureWarning: The provided callable <function median at 0x103d85120> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   data_df.groupby("Outlet_Location_Type")["Item_Weight"].agg([np.mean, np.median])
#                            mean  median
# Outlet_Location_Type
# Tier 1                12.892124  12.625
# Tier 2                12.768628  12.500
# ...

# %%
data_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### The Item_Fat_Content and Item_Type will affect the Item_Weight, don’t you think? So, let’s group the DataFrame by these columns and handle the missing weights using the mean of these groups:

# %%
data_df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data_df["Item_Weight"]=data_df.groupby(["Item_Type", "Item_Fat_Content"])["Item_Weight"].transform(lambda x : x.fillna(x.mean()))

# %%
#Slice by rows

# %%
data_df[0:3]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
# 2           FDN15        17.50          Low Fat         0.016760         Meat
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700

# %%
# 2. Slice by columns using labels

# %%
data_df[["Item_Fat_Content", "Item_Visibility"]]
# Out:
#      Item_Fat_Content  Item_Visibility
# 0             Low Fat         0.016047
# 1             Regular         0.019278
# 2             Low Fat         0.016760
# 3             Regular         0.000000
# 4             Low Fat         0.000000
# ...               ...              ...
# 8518          Low Fat         0.056783
# 8519          Regular         0.046982
# 8520          Low Fat         0.035186
# 8521          Regular         0.145221
# 8522          Low Fat         0.044878
#
# [8523 rows x 2 columns]

# %%
# Slice by .loc (label-based)


data_df.loc[0:2, "Item_Fat_Content":"Item_MRP"]
# Out:
#   Item_Fat_Content  Item_Visibility    Item_Type  Item_MRP
# 0          Low Fat         0.016047        Dairy  249.8092
# 1          Regular         0.019278  Soft Drinks   48.2692
# 2          Low Fat         0.016760         Meat  141.6180

# %%
data_df.iloc[1:6, 0:2]
# Out:
#   Item_Identifier  Item_Weight
# 1           DRC01        5.920
# 2           FDN15       17.500
# 3           FDX07       19.200
# 4           NCD19        8.930
# 5           FDP36       10.395

# %%
numbers = [10, 20, 30, 40, 50, 60, 70]

# %%
numbers[-1:0:-2]
# Out:
# [70, 50, 30]

# %%
data_df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
data_df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
list1 = [2,4,5,6,7]
list2 = [7,9.19,7]

# %%
list1.extend(list2)

# %%
list1
# Out:
# [2, 4, 5, 6, 7, 7, 9.19, 7]

# %%
#find prime number

# %%
def check_prime(n):

    if n ==1:
        return True
    elif n ==2:
        return True

    else:
        for i in range(2, int(n**0.5) +1):
            if n %i ==0:
                return False

        return True

# %%
check_prime(13)
# Out:
# True

# %%
lis1= [1,55,66,32,12,13,11,1,55,66,2]

[check_prime(x) for x in lis1]
# Out:
# [True, False, False, False, False, True, True, True, False, False, True]

# %%
def welcome(fx):
    def mfx(*t, **d):
        print("Before hellow")
        fx(*t,**d)
        print("After hellow")
    return mfx

@welcome
def hhi():
    print("gejj")

# %%
hhi()
# Out:
# Before hellow
# gejj
# After hellow

# %%
lis1= [1,55,66,32,12,13,11,1,55,66,2]

["Even" if x%2==0  else "odd" for x in lis1 ]
# Out:
# ['odd',
#  'odd',
#  'Even',
#  'Even',
#  'Even',
#  'odd',
#  'odd',
#  'odd',
#  'odd',
#  'Even',
#  'Even']

# %%
list1.pop(1)
# Out:
# 4

# %%
list1
# Out:
# [2, 5, 6, 7, 7, 9.19, 7]

# %%
list1.pop()
# Out:
# 7

# %%
list1
# Out:
# [2, 5, 6, 7, 7, 9.19]

# %%
list1.pop(1)
# Out:
# 5

# %%
list1
# Out:
# [2, 6, 7, 7, 9.19]

# %%
import pandas as pd

# Prices table
Prices = pd.DataFrame({
    "product_id": [1, 1, 2, 2],
    "start_date": pd.to_datetime(["2019-02-17", "2019-03-01", "2019-02-01", "2019-02-21"]),
    "end_date": pd.to_datetime(["2019-02-28", "2019-03-22", "2019-02-20", "2019-03-31"]),
    "price": [5, 20, 15, 30]
})

# UnitsSold table
UnitsSold = pd.DataFrame({
    "product_id": [1, 1, 2, 2],
    "purchase_date": pd.to_datetime(["2019-02-25", "2019-03-01", "2019-02-10", "2019-03-22"]),
    "units": [100, 15, 200, 30]
})

# %%
merged = UnitsSold.merge(Prices, on="product_id", how="left")

# %%
merged
# Out:
#    product_id purchase_date  units start_date   end_date  price
# 0           1    2019-02-25    100 2019-02-17 2019-02-28      5
# 1           1    2019-02-25    100 2019-03-01 2019-03-22     20
# 2           1    2019-03-01     15 2019-02-17 2019-02-28      5
# 3           1    2019-03-01     15 2019-03-01 2019-03-22     20
# 4           2    2019-02-10    200 2019-02-01 2019-02-20     15
# 5           2    2019-02-10    200 2019-02-21 2019-03-31     30
# 6           2    2019-03-22     30 2019-02-01 2019-02-20     15
# 7           2    2019-03-22     30 2019-02-21 2019-03-31     30

# %%
merged = merged[
    (merged["purchase_date"] >= merged["start_date"]) &
    (merged["purchase_date"] <= merged["end_date"])
]

merged["revenue"] = merged["units"] * merged["price"]
# Out:
# /var/folders/00/rndss5vd6h9cdr24fwvnz6kw0000gp/T/ipykernel_3297/465084022.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged["revenue"] = merged["units"] * merged["price"]

# %%
merged
# Out:
#    product_id purchase_date  units start_date   end_date  price  revenue
# 0           1    2019-02-25    100 2019-02-17 2019-02-28      5      500
# 3           1    2019-03-01     15 2019-03-01 2019-03-22     20      300
# 4           2    2019-02-10    200 2019-02-01 2019-02-20     15     3000
# 7           2    2019-03-22     30 2019-02-21 2019-03-31     30      900

# %%
result = (
    merged.groupby("product_id", as_index=False)
          .agg(
              total_revenue=("revenue", "sum"),
              total_units=("units", "sum")
          )
)

# %%
result
# Out:
#    product_id  total_revenue  total_units
# 0           1            800          115
# 1           2           3900          230
