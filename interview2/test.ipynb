# %%
Table 1:
EmpId EmpName
 
 
Table 2:
EmpId ExpenseType ExpenseAmnt Month
 
 
Output Table
EmpName TotalAmnt Month

# %%
select EmpName , sum(ExpenseAmnt) as TotalAmnt , Month from (select * from tb1 inner_join tb2 on tbl.empid == tb2.emp_id) as tb3 group by Month, EmpName

# %%
df3 = tb1.merge(tb2, how = inner, on= EmpId)
df3.groupy(Month,EmpName)[ExpenseAmnt].sum().reset_index()
df3.groupy(Month,EmpName)[ExpenseAmnt].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df3 = tb1.merge(tb2, how = "inner", on= "EmpId")
#       2 df3.groupy("Month","EmpName")["ExpenseAmnt"].sum().reset_index()
#
# NameError: name 'tb1' is not defined

# %%
df3.groupy(Month,EmpName)[ExpenseAmnt].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df3.groupy(Month,EmpName)[ExpenseAmnt].sum()
#
# NameError: name 'df3' is not defined
